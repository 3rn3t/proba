# %%
import numpy as np
import matplotlib.pyplot as plt
import math

k = [3,4,5,6,7,8]
P = [4/20,1/20,3/20,7/20,2/20,3/20]
moy = 0
ex2 = 0

for i in range(len(k)):
    moy += k[i]*P[i] 
    ex2 += (k[i]**2)*P[i]

ecart_type = math.sqrt(ex2 - moy**2)

plt.figure() #affichage de l'histogramme
plt.bar(k,P,label="Loi de X",color='gray')
plt.ylabel("P(X = k)")
plt.xlabel("k (valeurs de X)")
plt.legend(loc="upper right")
plt.text(6.5, 0.3, s = 'Moyenne : '+str(round(moy,2)))  
plt.text(6.5, 0.275, s = ' Ecart-type : '+str(round(ecart_type,2)))
plt.show()

convolution = np.convolve(x,y)
