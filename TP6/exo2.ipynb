# %%
import numpy as np
import matplotlib.pyplot as plt


N = 10000

x = np.random.rand(N)
y = np.random.rand(N)


X = np.zeros((N,1))
Y = np.zeros((N,1))

X = np.sqrt(-2*np.log(x))*np.cos(2*np.pi*y)
Y = np.sqrt(-2*np.log(x))*np.sin(2*np.pi*y)

plt.scatter(X,Y)
plt.axis('equal')
# Out:
# (np.float64(-4.2311911239102),
#  np.float64(5.177116615264579),
#  np.float64(-4.452582269516215),
#  np.float64(4.571803264904844))
